# %%
import sys

import os
from pathlib import Path
import copy
import numpy as np
import torch


ROOT_SCRATCH = os.path.abspath("..")  # adjust if needed
PTT_PATH = os.path.join(ROOT_SCRATCH, "PTT")
ROOT_PROJECT = Path('/storage/project/r-gchou3-0/spanse30')
MSF_PATH = os.path.join(ROOT_PROJECT, "MSF")
# sys.path.insert(0, MSF_PATH)

import sys
for k in list(sys.modules.keys()):
    if k.startswith("pcdet"):
        del sys.modules[k]
sys.path = [p for p in sys.path if "OpenPCDet" not in p]
sys.path.insert(0, MSF_PATH)

import pcdet
print("Now using:", pcdet.__file__)

from pcdet.config import cfg, cfg_from_yaml_file
from pcdet.datasets import build_dataloader
from pcdet.models import build_network, load_data_to_gpu
from pcdet.utils import common_utils

from pcdet.config import cfg, cfg_from_yaml_file
cfg.clear()


CFG_FILE = MSF_PATH + '/tools/cfgs/waymo_models/msf_4frames.yaml' 
CKPT = MSF_PATH + '/output/cfgs/waymo_models/msf_4frames/default/ckpt/checkpoint_epoch_6.pth'  # <- put your ckpt here

cfg_from_yaml_file(CFG_FILE, cfg)
cfg.TAG = Path(CFG_FILE).stem
cfg.EXP_GROUP_PATH = 'centerpoint_waymo_demo'

import os
# cfg.DATA_CONFIG.DATA_PATH = os.path.join(OPENPCDET_PATH, 'data', 'waymo')

logger = common_utils.create_logger()
logger.info(f'Loaded cfg from {CFG_FILE}')


dataset_msf, test_loader_msf, _ = build_dataloader(
    dataset_cfg=cfg.DATA_CONFIG,
    class_names=cfg.CLASS_NAMES,
    batch_size=1,
    dist=False,
    workers=4,
    logger=logger,
    training=False
)

len_test = len(dataset_msf)
logger.info(f'Test set length: {len_test}')
model_msf = build_network(
    model_cfg=cfg.MODEL,
    num_class=len(cfg.CLASS_NAMES),
    dataset=dataset_msf
)

logger.info(f'Loading checkpoint from: {CKPT}')
model_msf.load_params_from_file(filename=CKPT, logger=logger, to_cpu=False)
model_msf.cuda()
model_msf.eval()

data_iter = iter(test_loader_msf)
batch_dict_msf = next(data_iter)

load_data_to_gpu(batch_dict_msf)
# Out:
# 2026-03-18 14:53:19,648   INFO  Loaded cfg from /storage/project/r-gchou3-0/spanse30/MSF/tools/cfgs/waymo_models/msf_4frames.yaml
# 2026-03-18 14:53:19,648   INFO  Loaded cfg from /storage/project/r-gchou3-0/spanse30/MSF/tools/cfgs/waymo_models/msf_4frames.yaml
# 2026-03-18 14:53:19,649   INFO  Loading Waymo dataset
# 2026-03-18 14:53:19,649   INFO  Loading Waymo dataset
# Now using: /storage/project/r-gchou3-0/spanse30/MSF/pcdet/__init__.py
# 2026-03-18 14:53:21,292   INFO  Total skipped info 0
# 2026-03-18 14:53:21,292   INFO  Total skipped info 0
# 2026-03-18 14:53:21,293   INFO  Total samples for Waymo dataset: 38597
# 2026-03-18 14:53:21,293   INFO  Total samples for Waymo dataset: 38597
# 2026-03-18 14:53:21,294   INFO  Loading and reorganizing pred_boxes to dict from path: /storage/project/r-gchou3-0/spanse30/OpenPCDet/output/cfgs/custom_models/centerpoint_multiframe_waymo/default/eval/epoch_36/val/default/result_fixed.pkl
# 2026-03-18 14:53:21,294   INFO  Loading and reorganizing pred_boxes to dict from path: /storage/project/r-gchou3-0/spanse30/OpenPCDet/output/cfgs/custom_models/centerpoint_multiframe_waymo/default/eval/epoch_36/val/default/result_fixed.pkl
# 2026-03-18 14:53:24,904   INFO  Predicted boxes has been loaded, total sequences: 202
# 2026-03-18 14:53:24,904   INFO  Predicted boxes has been loaded, total sequences: 202
# 2026-03-18 14:53:25,272   INFO  Test set length: 38597
# 2026-03-18 14:53:25,272   INFO  Test set length: 38597
# 2026-03-18 14:53:25,590   INFO  Loading checkpoint from: /storage/project/r-gchou3-0/spanse30/MSF/output/cfgs/waymo_models/msf_4frames/default/ckpt/checkpoint_epoch_6.pth
# 2026-03-18 14:53:25,590   INFO  Loading checkpoint from: /storage/project/r-gchou3-0/spanse30/MSF/output/cfgs/waymo_models/msf_4frames/default/ckpt/checkpoint_epoch_6.pth
# 2026-03-18 14:53:25,595   INFO  ==> Loading parameters from checkpoint /storage/project/r-gchou3-0/spanse30/MSF/output/cfgs/waymo_models/msf_4frames/default/ckpt/checkpoint_epoch_6.pth to GPU
# 2026-03-18 14:53:25,595   INFO  ==> Loading parameters from checkpoint /storage/project/r-gchou3-0/spanse30/MSF/output/cfgs/waymo_models/msf_4frames/default/ckpt/checkpoint_epoch_6.pth to GPU
# 2026-03-18 14:53:25,842   INFO  ==> Checkpoint trained from version: pcdet+0.6.0+60735d2
# 2026-03-18 14:53:25,842   INFO  ==> Checkpoint trained from version: pcdet+0.6.0+60735d2
# 2026-03-18 14:53:25,849   INFO  ==> Done (loaded 200/200)
# 2026-03-18 14:53:25,849   INFO  ==> Done (loaded 200/200)

# %%
import sys
for k in list(sys.modules.keys()):
    if k.startswith("pcdet"):
        del sys.modules[k]
sys.path = [p for p in sys.path if "MSF" not in p]
sys.path.insert(0, PTT_PATH)

import pcdet
print("Now using:", pcdet.__file__)

from pcdet.config import cfg, cfg_from_yaml_file
from pcdet.datasets import build_dataloader
from pcdet.models import build_network, load_data_to_gpu
from pcdet.utils import common_utils
# Out:
# Now using: /storage/scratch1/9/spanse30/PTT/pcdet/__init__.py

# %%
from pcdet.config import cfg, cfg_from_yaml_file
cfg.clear()


CFG_FILE = 'tools/cfgs/waymo_models/ptt_32frames.yaml' 
CKPT = 'output/cfgs/waymo_models/default/checkpoint_epoch_6.pth'  # <- put your ckpt here

cfg_from_yaml_file(CFG_FILE, cfg)
cfg.TAG = Path(CFG_FILE).stem
cfg.EXP_GROUP_PATH = 'centerpoint_waymo_demo'

# cfg.DATA_CONFIG.DATA_PATH = os.path.join(OPENPCDET_PATH, 'data', 'waymo')

logger = common_utils.create_logger()
logger.info(f'Loaded cfg from {CFG_FILE}')


dataset_ptt, test_loader_ptt, _ = build_dataloader(
    dataset_cfg=cfg.DATA_CONFIG,
    class_names=cfg.CLASS_NAMES,
    batch_size=1,
    dist=False,
    workers=4,
    logger=logger,
    training=False
)

len_test = len(dataset_ptt)
logger.info(f'Test set length: {len_test}')
model_ptt = build_network(
    model_cfg=cfg.MODEL,
    num_class=len(cfg.CLASS_NAMES),
    dataset=dataset_ptt
)

logger.info(f'Loading checkpoint from: {CKPT}')
model_ptt.load_params_from_file(filename=CKPT, logger=logger, to_cpu=False)
model_ptt.cuda()
model_ptt.eval()

data_iter = iter(test_loader_ptt)
batch_dict_ptt = next(data_iter)

load_data_to_gpu(batch_dict_ptt)
# Out:
# 2026-03-18 14:55:27,599   INFO  Loaded cfg from tools/cfgs/waymo_models/ptt_32frames.yaml
# 2026-03-18 14:55:27,599   INFO  Loaded cfg from tools/cfgs/waymo_models/ptt_32frames.yaml
# 2026-03-18 14:55:27,599   INFO  Loaded cfg from tools/cfgs/waymo_models/ptt_32frames.yaml
# 2026-03-18 14:55:27,599   INFO  Loaded cfg from tools/cfgs/waymo_models/ptt_32frames.yaml
# 2026-03-18 14:55:27,599   INFO  Loaded cfg from tools/cfgs/waymo_models/ptt_32frames.yaml
# 2026-03-18 14:55:27,601   INFO  Loading Waymo dataset
# 2026-03-18 14:55:27,601   INFO  Loading Waymo dataset
# 2026-03-18 14:55:27,601   INFO  Loading Waymo dataset
# 2026-03-18 14:55:27,601   INFO  Loading Waymo dataset
# 2026-03-18 14:55:27,601   INFO  Loading Waymo dataset
# 2026-03-18 14:55:29,091   INFO  Total skipped info 0
# 2026-03-18 14:55:29,091   INFO  Total skipped info 0
# 2026-03-18 14:55:29,091   INFO  Total skipped info 0
# 2026-03-18 14:55:29,091   INFO  Total skipped info 0
# 2026-03-18 14:55:29,091   INFO  Total skipped info 0
# 2026-03-18 14:55:29,093   INFO  Total samples for Waymo dataset: 38597
# 2026-03-18 14:55:29,093   INFO  Total samples for Waymo dataset: 38597
# 2026-03-18 14:55:29,093   INFO  Total samples for Waymo dataset: 38597
# 2026-03-18 14:55:29,093   INFO  Total samples for Waymo dataset: 38597
# 2026-03-18 14:55:29,093   INFO  Total samples for Waymo dataset: 38597
# 2026-03-18 14:55:29,094   INFO  Loading and reorganizing pred_boxes to dict from path: /storage/project/r-gchou3-0/spanse30/OpenPCDet/output/cfgs/custom_models/centerpoint_multiframe_waymo/default/eval/epoch_36/val/default/result_fixed.pkl
# 2026-03-18 14:55:29,094   INFO  Loading and reorganizing pred_boxes to dict from path: /storage/project/r-gchou3-0/spanse30/OpenPCDet/output/cfgs/custom_models/centerpoint_multiframe_waymo/default/eval/epoch_36/val/default/result_fixed.pkl
# 2026-03-18 14:55:29,094   INFO  Loading and reorganizing pred_boxes to dict from path: /storage/project/r-gchou3-0/spanse30/OpenPCDet/output/cfgs/custom_models/centerpoint_multiframe_waymo/default/eval/epoch_36/val/default/result_fixed.pkl
# 2026-03-18 14:55:29,094   INFO  Loading and reorganizing pred_boxes to dict from path: /storage/project/r-gchou3-0/spanse30/OpenPCDet/output/cfgs/custom_models/centerpoint_multiframe_waymo/default/eval/epoch_36/val/default/result_fixed.pkl
# 2026-03-18 14:55:29,094   INFO  Loading and reorganizing pred_boxes to dict from path: /storage/project/r-gchou3-0/spanse30/OpenPCDet/output/cfgs/custom_models/centerpoint_multiframe_waymo/default/eval/epoch_36/val/default/result_fixed.pkl
# 2026-03-18 14:55:32,118   INFO  Predicted boxes has been loaded, total sequences: 202
# 2026-03-18 14:55:32,118   INFO  Predicted boxes has been loaded, total sequences: 202
# 2026-03-18 14:55:32,118   INFO  Predicted boxes has been loaded, total sequences: 202
# 2026-03-18 14:55:32,118   INFO  Predicted boxes has been loaded, total sequences: 202
# 2026-03-18 14:55:32,118   INFO  Predicted boxes has been loaded, total sequences: 202
# 2026-03-18 14:55:32,167   INFO  Test set length: 38597
# 2026-03-18 14:55:32,167   INFO  Test set length: 38597
# 2026-03-18 14:55:32,167   INFO  Test set length: 38597
# 2026-03-18 14:55:32,167   INFO  Test set length: 38597
# 2026-03-18 14:55:32,167   INFO  Test set length: 38597
# 2026-03-18 14:55:32,200   INFO  Loading checkpoint from: output/cfgs/waymo_models/default/checkpoint_epoch_6.pth
# 2026-03-18 14:55:32,200   INFO  Loading checkpoint from: output/cfgs/waymo_models/default/checkpoint_epoch_6.pth
# 2026-03-18 14:55:32,200   INFO  Loading checkpoint from: output/cfgs/waymo_models/default/checkpoint_epoch_6.pth
# 2026-03-18 14:55:32,200   INFO  Loading checkpoint from: output/cfgs/waymo_models/default/checkpoint_epoch_6.pth
# 2026-03-18 14:55:32,200   INFO  Loading checkpoint from: output/cfgs/waymo_models/default/checkpoint_epoch_6.pth
# 2026-03-18 14:55:32,221   INFO  ==> Loading parameters from checkpoint output/cfgs/waymo_models/default/checkpoint_epoch_6.pth to GPU
# 2026-03-18 14:55:32,221   INFO  ==> Loading parameters from checkpoint output/cfgs/waymo_models/default/checkpoint_epoch_6.pth to GPU
# 2026-03-18 14:55:32,221   INFO  ==> Loading parameters from checkpoint output/cfgs/waymo_models/default/checkpoint_epoch_6.pth to GPU
# 2026-03-18 14:55:32,221   INFO  ==> Loading parameters from checkpoint output/cfgs/waymo_models/default/checkpoint_epoch_6.pth to GPU
# 2026-03-18 14:55:32,221   INFO  ==> Loading parameters from checkpoint output/cfgs/waymo_models/default/checkpoint_epoch_6.pth to GPU
# 2026-03-18 14:55:32,711   INFO  ==> Checkpoint trained from version: pcdet+0.6.0+83690fd
# 2026-03-18 14:55:32,711   INFO  ==> Checkpoint trained from version: pcdet+0.6.0+83690fd
# 2026-03-18 14:55:32,711   INFO  ==> Checkpoint trained from version: pcdet+0.6.0+83690fd
# 2026-03-18 14:55:32,711   INFO  ==> Checkpoint trained from version: pcdet+0.6.0+83690fd
# 2026-03-18 14:55:32,711   INFO  ==> Checkpoint trained from version: pcdet+0.6.0+83690fd
# 2026-03-18 14:55:32,719   INFO  ==> Done (loaded 264/264)
# 2026-03-18 14:55:32,719   INFO  ==> Done (loaded 264/264)
# 2026-03-18 14:55:32,719   INFO  ==> Done (loaded 264/264)
# 2026-03-18 14:55:32,719   INFO  ==> Done (loaded 264/264)
# 2026-03-18 14:55:32,719   INFO  ==> Done (loaded 264/264)

# %%
import time
import copy
import torch

def measure_forward_memory_and_latency(model, batch, n_warmup=3, n_runs=10, label="model"):
    assert torch.cuda.is_available(), "CUDA is required."

    # Warmup with a fresh copy each time
    with torch.no_grad():
        for _ in range(n_warmup):
            batch_dict = copy.deepcopy(batch)
            _ = model(batch_dict)
        torch.cuda.synchronize()

    latencies_ms = []
    peak_mem_bytes_runs = []

    for _ in range(n_runs):
        torch.cuda.empty_cache()
        torch.cuda.reset_peak_memory_stats()
        torch.cuda.synchronize()

        batch_dict = copy.deepcopy(batch)

        start = time.perf_counter()
        with torch.no_grad():
            _ = model(batch_dict)
        torch.cuda.synchronize()
        end = time.perf_counter()

        latencies_ms.append((end - start) * 1000.0)
        peak_mem_bytes_runs.append(torch.cuda.max_memory_allocated())

    peak_mem_bytes = max(peak_mem_bytes_runs)
    peak_mem_mb = peak_mem_bytes / (1024 ** 2)
    peak_mem_gb = peak_mem_bytes / (1024 ** 3)

    print(f"{label}")
    print(f"  Peak forward memory: {peak_mem_mb:.2f} MB ({peak_mem_gb:.3f} GB)")
    print(f"  Avg latency:         {sum(latencies_ms)/len(latencies_ms):.2f} ms")
    print(f"  Min latency:         {min(latencies_ms):.2f} ms")
    print(f"  Max latency:         {max(latencies_ms):.2f} ms")
    print(f"  Std latency:         {torch.tensor(latencies_ms).std(unbiased=False).item():.2f} ms")

    return {
        "peak_mem_bytes": peak_mem_bytes,
        "peak_mem_mb": peak_mem_mb,
        "peak_mem_gb": peak_mem_gb,
        "latencies_ms": latencies_ms,
        "avg_latency_ms": sum(latencies_ms)/len(latencies_ms),
        "min_latency_ms": min(latencies_ms),
        "max_latency_ms": max(latencies_ms),
        "std_latency_ms": torch.tensor(latencies_ms).std(unbiased=False).item(),
    }

# %%
data_iter = iter(test_loader_msf)
batch_dict_msf = next(data_iter)
load_data_to_gpu(batch_dict_msf)

# print(batch_dict_msf['roi_scores'].shape)
# print(batch_dict_msf.keys())

msf_stats = measure_forward_memory_and_latency(
    model_msf,
    batch_dict_msf,
    n_warmup=3,
    n_runs=10,
    label="MSF"
)

data_iter = iter(test_loader_ptt)
batch_dict_ptt = next(data_iter)
load_data_to_gpu(batch_dict_ptt)

# CenterPoint multi-frame
ptt_stats = measure_forward_memory_and_latency(
    model_ptt,
    batch_dict_ptt,
    n_warmup=3,
    n_runs=10,
    label="PTT"
)
# Out:
# MSF
#   Peak forward memory: 885.72 MB (0.865 GB)
#   Avg latency:         39.06 ms
#   Min latency:         38.77 ms
#   Max latency:         39.68 ms
#   Std latency:         0.27 ms
# PTT
#   Peak forward memory: 1356.79 MB (1.325 GB)
#   Avg latency:         71.19 ms
#   Min latency:         70.40 ms
#   Max latency:         71.82 ms
#   Std latency:         0.51 ms

# %%
# CenterPoint single-frame
msf_stats = measure_forward_memory_and_latency(
    model_msf,
    batch_dict_msf,
    n_warmup=3,
    n_runs=10,
    label="MSF"
)

# CenterPoint multi-frame
ptt_stats = measure_forward_memory_and_latency(
    model_ptt,
    batch_dict_ptt,
    n_warmup=3,
    n_runs=10,
    label="PTT"
)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[16], line 2
#       1 # CenterPoint single-frame
# ----> 2 msf_stats = measure_forward_memory_and_latency(
#       3     model_msf,
#       4     batch_dict_msf,
#       5     n_warmup=3,
#       6     n_runs=10,
#       7     label="MSF"
#       8 )
#      10 # CenterPoint multi-frame
#      11 ptt_stats = measure_forward_memory_and_latency(
#      12     model_ptt,
#      13     batch_dict_ptt,
#    (...)
#      16     label="PTT"
#      17 )
#
# Cell In[15], line 23, in measure_forward_memory_and_latency(model, batch, n_warmup, n_runs, label)
#      21 with torch.no_grad():
#      22     for _ in range(n_warmup):
# ---> 23         _ = model(batch_dict)
#      24     torch.cuda.synchronize()
#      26 latencies_ms = []
#
# File /storage/project/r-gchou3-0/spanse30/ptt_env/lib/python3.8/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File /storage/project/r-gchou3-0/spanse30/ptt_env/lib/python3.8/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File /storage/project/r-gchou3-0/spanse30/MSF/pcdet/models/detectors/msf.py:19, in MSF.forward(self, batch_dict)
#      17 def forward(self, batch_dict):
#      18     for cur_module in self.module_list[:]:
# ---> 19         batch_dict = cur_module(batch_dict)
#      21     if self.training:
#      22         loss, tb_dict, disp_dict = self.get_training_loss()
#
# File /storage/project/r-gchou3-0/spanse30/ptt_env/lib/python3.8/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File /storage/project/r-gchou3-0/spanse30/ptt_env/lib/python3.8/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File /storage/project/r-gchou3-0/spanse30/MSF/pcdet/models/roi_heads/msf_head.py:506, in MSFHead.forward(self, batch_dict)
#     503 cur_batch_boxes = copy.deepcopy(batch_dict['roi_boxes'].detach())
#     504 batch_dict['cur_frame_idx'] = 0
# --> 506 trajectory_rois = self.generate_trajectory_msf(cur_batch_boxes, batch_dict)
#     508 batch_dict['traj_memory'] = trajectory_rois
#     509 batch_dict['has_class_labels'] = True
#
# File /storage/project/r-gchou3-0/spanse30/MSF/pcdet/models/roi_heads/msf_head.py:482, in MSFHead.generate_trajectory_msf(self, cur_batch_boxes, batch_dict)
#     480 trajectory_rois[:, 0, :, :]= cur_batch_boxes
#     481 batch_dict['valid_length'] = torch.ones([batch_dict['batch_size'], num_frames,trajectory_rois.shape[2]])
# --> 482 batch_dict['roi_scores'] = batch_dict['roi_scores'][:, :, None].repeat(1, 1, num_frames)
#     484 # simply propagate proposal based on velocity
#     485 for i in range(1,num_frames):
#
# RuntimeError: Number of dimensions of repeat dims can not be smaller than number of dimensions of tensor

# %%
# Out:
# 0.0 GB allocated
# 0.075497472 GB reserved
# Now using: /storage/project/r-gchou3-0/spanse30/MSF/pcdet/__init__.py
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
batch_dict_msf.keys()
# Out:
# dict_keys(['sample_idx', 'poses', 'roi_boxes', 'roi_scores', 'roi_labels', 'points', 'frame_id', 'gt_boxes', 'use_lead_xyz', 'metadata', 'num_frames', 'batch_size', 'cur_frame_idx', 'valid_length', 'traj_memory', 'has_class_labels', 'trajectory_rois', 'valid_traj_mask', 'batch_box_preds', 'cls_preds_normalized', 'batch_cls_preds'])

# %%
batch_dict_msf['batch_box_preds'].shape
# Out:
# torch.Size([1, 88, 9])
